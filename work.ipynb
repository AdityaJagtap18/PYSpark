# %%
import os
import pandas as pd

folder_path = "data/hnm"
os.makedirs(folder_path, exist_ok=True)

# %%
import pandas as pd

url = "hf://datasets/einrafh/hnm-fashion-recommendations-data/data/raw/articles.csv"

df = pd.read_csv(url)

local_path = "data/hnm/articles.csv"
df.to_csv(local_path, index=False)

print(f"File saved at: {local_path}")
